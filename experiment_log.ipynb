# %% [markdown]
# zp_intel
#
# 1.
# 2019-2-26-21-51 focal[1,3] lr 0.01 FD_mobilenetv2_bs32  final_DW(3,2,1) fc nose //30
# FD-mobilenetv2-train.log
# [1, 16, 1, 2],
# [6, 32, 2, 2],
# [6, 48, 3, 2],
# [6, 64, 3, 2],
#  + Number of FLOPs: 61.84M
# The network has 250818 params.
# epoch: 36 EER: 0.005010 TPR@FPR=10E-2: 0.997526 TPR@FPR=10E-3: 0.971088 APCER:0.018597 NPCER:0.000668 AUC: 0.99985971 Acc:98.699 TN:6491 FP : 123 FN:2 TP:2992  ACER:0.00963246
#
# 2.
# 2019-2-26-21-50 focal[1,3] lr 0.01 FD_mobilenetv2_bs32-nofc  final_DW(3,2,1) nofc nose //30
# FD-mobilenetv2-nofc-train.log
# [1, 16, 1, 2],
# [6, 32, 2, 2],
# [6, 48, 3, 2],
# [6, 64, 3, 2],
#  + Number of FLOPs: 61.84M
#  The network has 248768 params.
# epoch: 35 EER: 0.002419 TPR@FPR=10E-2: 0.999332 TPR@FPR=10E-3: 0.989739 APCER:0.006501 NPCER:0.000668 AUC: 0.99992597 Acc:99.532 TN:6571 FP : 43 FN:2 TP:2992  ACER:0.00358468
#
# 3
# 2019-2-26-21-56 focal[1,3] lr 0.01 FD_mobilenet38_bs32-nofc  final_DW(3,2,1) nofc nose  //30
# [1, 16, 1, 2],
# [6, 32, 2, 2],
# [6, 48, 3, 2],
# [6, 64, 6, 2],
#  + Number of FLOPs: 69.69M
#  The network has 411584 params.
# epoch: 57 EER: 0.003931 TPR@FPR=10E-2: 0.999332 TPR@FPR=10E-3: 0.966934 APCER:0.015119 NPCER:0.000000 AUC: 0.99988320 Acc:98.959 TN:6514 FP : 100 FN:0 TP:2994  ACER:0.00755972
#
# 4
# 2019-2-26-21-59 focal[1,3] lr 0.01 FD_mobilenet38_bs32  final_DW(3,2,1) nofc nose //30
# [1, 16, 1, 2],
# [6, 32, 2, 2],
# [6, 48, 3, 2],
# [6, 64, 6, 2],
#  + Number of FLOPs: 69.69M
#  The network has 413634 params.
# epoch: 31 EER: 0.004008 TPR@FPR=10E-2: 0.998470 TPR@FPR=10E-3: 0.978495 APCER:0.012096 NPCER:0.001336 AUC: 0.99991026 Acc:99.126 TN:6534 FP : 80 FN:4 TP:2990  ACER:0.00671578
#
#
# 5
# FD_mobilenet38_bs32_2 final_DW(3,2,1) fc
# 2019-2-27-13:33
# [1, 16, 1, 2],
# [6, 32, 2, 2],
# [6, 48, 6, 2],
# [6, 64, 3, 2],
# nohup python main.py --config="cfgs/FD-mobilenetv2.yaml"  --every-decay 60 -b 32 --lr 0.01 --fl-gamma 3 >> FD-mobilenet38-fc-2train.log &
#  + Number of FLOPs: 79.99M
#  The network has 345282 params.
# epoch: 42 EER: 0.002672 TPR@FPR=10E-2: 1.000000 TPR@FPR=10E-3: 0.994398 APCER:0.006501 NPCER:0.000000 AUC: 0.99997627 Acc:99.552 TN:6571 FP : 43 FN:0 TP:2994  ACER:0.00325068
#
# 5-1
# FD_mobilenet38_bs32_2 GAP fc
# /FD_mobilenet38_bs32-fc-nose-gpa
# 2019-2-27-20:04
# [1, 16, 1, 2],
# [6, 32, 2, 2],
# [6, 48, 6, 2],
# [6, 64, 3, 2],
# nohup python main.py --config="cfgs/FD-mobilenetv2.yaml"  --every-decay 60 -b 32 --lr 0.01 --fl-gamma 3 >> FD-mobilenet38-nofc-GPA-train.log &
#  + Number of FLOPs: 83.24M
#  The network has 412290 params.
# epoch: 90 EER: 0.002959 TPR@FPR=10E-2: 0.999332 TPR@FPR=10E-3: 0.952536 APCER:0.009828 NPCER:0.000668 AUC: 0.99980962 Acc:99.303 TN:6549 FP : 65 FN:2 TP:2992  ACER:0.00524782
#
# 6
# FD_mobilenet38_bs32-nofc final_DW(3,2,1) nofc
# 2019-2-27-13:45
# [1, 16, 1, 2],
# [6, 32, 2, 2],
# [6, 48, 6, 2],
# [6, 64, 3, 2],
# nohup python main.py --config="cfgs/FD-mobilenetv2.yaml"  --every-decay 60 -b 32 --lr 0.01 --fl-gamma 3 >> FD-mobilenet38-nofc-2train.log &
#  + Number of FLOPs: 79.98M
#  The network has 343232 params.
# epoch: 53 EER: 0.002476 TPR@FPR=10E-2: 0.999332 TPR@FPR=10E-3: 0.993343 APCER:0.006048 NPCER:0.001002 AUC: 0.99997419 Acc:99.552 TN:6574 FP : 40 FN:3 TP:2991  ACER:0.00352489
#
# 7-0
# FD_mobilenet38_bs32-fc-nose final_DW(3,2,1) fc nose
# 2019-2-27-12:23
# [1, 16, 1, 2],
# [6, 32, 2, 2],
# [6, 48, 6, 2],
# [6, 64, 3, 2],
# nohup python main.py --config="cfgs/FD-mobilenetv2.yaml"  --every-decay 60 -b 32 --lr 0.01 --fl-gamma 3 >> FD-mobilenet38-fc-nose-train.log &
#  + Number of FLOPs: 79.99M
#  The network has 345282 params.
# epoch: 42 EER: 0.002672 TPR@FPR=10E-2: 1.000000 TPR@FPR=10E-3: 0.994398 APCER:0.006501 NPCER:0.000000 AUC: 0.99997627 Acc:99.552 TN:6571 FP : 43 FN:0 TP:2994  ACER:0.00325068
#
#
# 7
# FD_mobilenet38_bs32-nofc-se final_DW(3,2,1) nofc se
# 2019-2-27-13:49
# [1, 16, 1, 2],
# [6, 32, 2, 2],
# [6, 48, 6, 2],
# [6, 64, 3, 2],
# nohup python main.py --config="cfgs/FD-mobilenetv2.yaml"  --every-decay 60 -b 32 --lr 0.01 --fl-gamma 3 >> FD-mobilenet38-nofc-se-2train.log &
#  + Number of FLOPs: 79.99M
#  The network has 345332 params.
# epoch: 112 EER: 0.001670 TPR@FPR=10E-2: 0.999666 TPR@FPR=10E-3: 0.986071 APCER:0.003477 NPCER:0.000668 AUC: 0.99990456 Acc:99.740 TN:6591 FP : 23 FN:2 TP:2992  ACER:0.00207274
#
#
# 7-1
# FD_mobilenet38_bs32-nofc-se-avgdown2 final_DW(3,2,1) nofc se down 保留第一个下采样avg，下采样t=6
# 2019-2-28-10:30
# [1, 16, 1, 2],
# [6, 32, 2, 2],
# [6, 48, 6, 2],
# [6, 64, 3, 2],
# nohup python main.py --config="cfgs/FD-mobilenetv2.yaml"  --every-decay 60 -b 32 --lr 0.01 --fl-gamma 3 >> FD-mobilenet38-nofc-se-avgdown2-train.log &
#  + Number of FLOPs: 83.05M
#  The network has 351220 params.
# epoch: 35 EER: 0.002338 TPR@FPR=10E-2: 0.999332 TPR@FPR=10E-3: 0.996262 APCER:0.004536 NPCER:0.001670 AUC: 0.99997793 Acc:99.636 TN:6584 FP : 30 FN:5 TP:2989  ACER:0.00310292
# epoch: 79 EER: 0.001210 TPR@FPR=10E-2: 0.999666 TPR@FPR=10E-3: 0.998330 APCER:0.004385 NPCER:0.000334 AUC: 0.99990562 Acc:99.688 TN:6585 FP : 29 FN:1 TP:2993  ACER:0.00235932
#
# 7-2
# FD_mobilenet38_bs32-nofc-nose-avgdown2 final_DW(3,2,1) nofc nose down 保留第一个下采样avg，下采样t=6
# 2019-2-28-10:39
# [1, 16, 1, 2],
# [6, 32, 2, 2],
# [6, 48, 6, 2],
# [6, 64, 3, 2],
# nohup python main.py --config="cfgs/FD-mobilenetv2.yaml"  --every-decay 60 -b 32 --lr 0.01 --fl-gamma 3 >> FD-mobilenet38-nofc-nose-avgdown2-train.log &
#  + Number of FLOPs: 83.05M
#  The network has 349120 params.
# epoch: 40 EER: 0.001858 TPR@FPR=10E-2: 0.999332 TPR@FPR=10E-3: 0.998133 APCER:0.006501 NPCER:0.000668 AUC: 0.99998152 Acc:99.532 TN:6571 FP : 43 FN:2 TP:2992  ACER:0.00358468
#
# 7-3
# FD_mobilenet38_bs32-fc-nose-avgdown2 final_DW(3,2,1) fc nose down 保留第一个下采样avg，下采样t=6
# 2019-2-28-12:45
# [1, 16, 1, 2],
# [6, 32, 2, 2],
# [6, 48, 6, 2],
# [6, 64, 3, 2],
# nohup python main.py --config="cfgs/FD-mobilenetv2.yaml"  --every-decay 60 -b 32 --lr 0.01 --fl-gamma 3 >> FD-mobilenet38-fc-nose-avgdown2-train.log &
#  + Number of FLOPs: 83.05M
#  The network has 351170 params.
# epoch: 57 EER: 0.003174 TPR@FPR=10E-2: 0.999666 TPR@FPR=10E-3: 0.955244 APCER:0.009525 NPCER:0.000334 AUC: 0.99982053 Acc:99.334 TN:6551 FP : 63 FN:1 TP:2993  ACER:0.00492963
#
#
# 8
# FD_mobilenet38_bs32-nofc-se-2 final_DW(4,1) nofc se
# 2019-2-27-14:14
# [1, 16, 1, 2],
# [6, 32, 2, 2],
# [6, 48, 6, 2],
# [6, 64, 3, 2],
# nohup python main.py --config="cfgs/FD-mobilenetv2.yaml"  --every-decay 60 -b 32 --lr 0.01 --fl-gamma 3 >> FD-mobilenet38-nofc-se2-2train.log &
#  + Number of FLOPs: 79.99M
#  The network has 345780 params.
# epoch: 62 EER: 0.003331 TPR@FPR=10E-2: 0.999666 TPR@FPR=10E-3: 0.982298 APCER:0.010130 NPCER:0.000334 AUC: 0.99993268 Acc:99.292 TN:6547 FP : 67 FN:1 TP:2993  ACER:0.00523201
#
# 9
# FD_mobilenet38_bs32-nofc-nose-avgdown final_DW(3,2,1) nofc nose down t=4
# 2019-2-27-15:36
# [1, 16, 1, 2],
# [6, 32, 2, 2],
# [6, 48, 6, 2],
# [6, 64, 3, 2],
# nohup python main.py --config="cfgs/FD-mobilenetv2.yaml"  --every-decay 60 -b 32 --lr 0.01 --fl-gamma 3 >> FD-mobilenet38-nofc-nose-avgdown-train.log &
#  + Number of FLOPs: 76.64M
#  The network has 329216 params.
# epoch: 78 EER: 0.002004 TPR@FPR=10E-2: 0.999666 TPR@FPR=10E-3: 0.987308 APCER:0.005443 NPCER:0.000334 AUC: 0.99996026 Acc:99.615 TN:6578 FP : 36 FN:1 TP:2993  ACER:0.00288850
#
# 10
# FD_mobilenet38_bs32-nofc-se-avgdown final_DW(3,2,1) nofc se down t=4
# 2019-2-27-15:48
# [1, 16, 1, 2],
# [6, 32, 2, 2],
# [6, 48, 6, 2],
# [6, 64, 3, 2],
# nohup python main.py --config="cfgs/FD-mobilenetv2.yaml"  --every-decay 50 -b 32 --lr 0.01 --fl-gamma 3 >> FD-mobilenet38-nofc-se-avgdown-train.log &
#  + Number of FLOPs: 76.64M
#  The network has 331316 params.
# 31 EER: 0.002419 TPR@FPR=10E-2: 0.999666 TPR@FPR=10E-3: 0.995529 APCER:0.006048 NPCER:0.000334 AUC: 0.99997702 Acc:99.573 TN:6574 FP : 40 FN:1 TP:2993  ACER:0.00319089
#
#
# zp
#
#
# 11
# FD_mobilenet38_bs32-nofc-se-avgdown2 final_DW(3,2,1) nofc se down t=4  去掉第二次下采样种的支路
# 2019-2-27-15:48
# [1, 16, 1, 2],
# [6, 32, 2, 2],
# [6, 48, 6, 2],
# [6, 64, 3, 2],
# nohup python main.py --config="cfgs/FD-mobilenetv2.yaml"  --every-decay 50 -b 32 --lr 0.01 --fl-gamma 3 >> FD-mobilenet38-nofc-se-avgdown-2train.log &
#  + Number of FLOPs: 74.53M
#  The network has 330740 params.
# epoch: 32 EER: 0.003340 TPR@FPR=10E-2: 1.000000 TPR@FPR=10E-3: 0.988899 APCER:0.009676 NPCER:0.000000 AUC: 0.99992152 Acc:99.334 TN:6550 FP : 64       FN:0 TP:2994  ACER:0.00483822
#
#
#
#
# 12
# 2019-2-17-18:51
# FD_mobilenet43_bs32-nofc-se-avgdown2 final_DW(3,2,1) nofc se down t=4  去掉第二次下采样种的支路
#  t, c, n, s
# [1, 16, 1, 2],
# [6, 32, 3, 2], # 56x
# [6, 48, 6, 2], # 14x
# [6, 64, 4, 2], # 7x7
# + Number of FLOPs: 88.46M
# The network has 399860 params
# nohup python main.py --config="cfgs/FD-mobilenetv2.yaml"  --every-decay 50 -b 32 --lr 0.01 --fl-gamma 3 >> FD-mobilenet43-nofc-se-avgdown-2train.log &
# epoch: 36 EER: 0.002721 TPR@FPR=10E-2: 1.000000 TPR@FPR=10E-3: 0.994592 APCER:0.006804 NPCER:0.000334 AUC: 0.99997753 Acc:99.521 TN:6569 FP : 45       FN:1 TP:2993  ACER:0.00356888
#
# 13
# final_DW(4,1)
# 2019-2-17-18:54
# 88.47M
# 400308
# FD_mobilenet43_bs32-nofc-se-avgdown
# nohup python main.py --config="cfgs/FD-mobilenetv2.yaml"  --every-decay 50 -b 32 --lr 0.01 --fl-gamma 3 >> FD-mobilenet43-nofc-se-avgdown-train.log &
# epoch: 44 EER: 0.005292 TPR@FPR=10E-2: 0.998929 TPR@FPR=10E-3: 0.978958 APCER:0.006350 NPCER:0.002672 AUC: 0.99989870 Acc:99.480 TN:6572 FP : 42       FN:8 TP:2986  ACER:0.00451109
#
#
# 14
# 2019-2-17-19:33
# FD_mobilenet49_bs32-nofc-se-avgdown final_DW(3,2,1) nofc se down t=4  去掉第二次下采样种的支路
#  t, c, n, s
# [1, 16, 1, 2],
# [6, 32, 5, 2], # 56x56
# [6, 48, 6, 2], # 14x14
# [6, 64, 4, 2], # 7x7
# + Number of FLOPs: 111.10M
# The network has 429556 params
# nohup python main.py --config="cfgs/FD-mobilenetv2.yaml"  --every-decay 50 -b 32 --lr 0.01 --fl-gamma 3 >> FD-mobilenet49-nofc-se-avgdown-train.log &
# epoch: 66 EER: 0.002116 TPR@FPR=10E-2: 0.999666 TPR@FPR=10E-3: 0.995658 APCER:0.005745 NPCER:0.000334 AUC: 0.99996309 Acc:99.594 TN:6576 FP : 38       FN:1 TP:2993  ACER:0.00303969
#
# 15
# 2019-2-17-19:35
# FD_mobilenet49_bs32-fc-se-avgdown final_DW(3,2,1) nofc se down t=4  去掉第二次下采样种的支路
#  t, c, n, s
# [1, 16, 1, 2],
# [6, 32, 5, 2], # 56x56
# [6, 48, 6, 2], # 14x14
# [6, 64, 4, 2], # 7x7
# + Number of FLOPs: 111.10M
# The network has 431606 params
# nohup python main.py --config="cfgs/FD-mobilenetv2.yaml"  --every-decay 50 -b 32 --lr 0.01 --fl-gamma 3 >> FD-mobilenet49-fc-se-avgdown-train.log &
# epoch: 72 EER: 0.003006 TPR@FPR=10E-2: 0.999666 TPR@FPR=10E-3: 0.977815 APCER:0.008467 NPCER:0.000334 AUC: 0.99989920 Acc:99.407 TN:6558 FP : 56       FN:1 TP:2993  ACER:0.00440044
#
#
# zp/libxcam
# 7
# epoch: 112 EER: 0.001670 TPR@FPR=10E-2: 0.999666 TPR@FPR=10E-3: 0.986071 APCER:0.003477 NPCER:0.000668 AUC: 0.99990456 Acc:99.740 TN:6591 FP : 23 FN:2 TP:2992  ACER:0.00207274
# zp ../mobilelivenetA_bs32/
# 复现7  mobilelivefaceA
# 2019-2-28-14:00
# nohup python main.py --config="cfgs/MobileLiveNetA-32.yaml" --b 32 --lr 0.01  --every-decay 60 --fl-gamma 3 >> MobileLiveNetA-bs32--train.log &
# epoch: 38 EER: 0.003095 TPR@FPR=10E-2: 1.000000 TPR@FPR=10E-3: 0.985638 APCER:0.006501 NPCER:0.000668 AUC: 0.99993965 Acc:99.532 TN:6571 FP : 43 FN:2 TP:2992  ACER:0.00358468
# nohup python main.py --config="cfgs/MobileLiveNetA-32.yaml" --b 32 --lr 0.01  --every-decay 60 --fl-gamma 3 >> MobileLiveNetA-bs32--2train.log &
# epoch: 36 EER: 0.003931 TPR@FPR=10E-2: 0.999332 TPR@FPR=10E-3: 0.987111 APCER:0.002268 NPCER:0.006346 AUC: 0.99994203 Acc:99.646 TN:6599 FP : 15 FN:19 TP:2975  ACER:0.00430697
# nohup python main.py --config="cfgs/MobileLiveNetA-32.yaml" --b 32 --lr 0.01  --every-decay 60 --fl-gamma 3 >> MobileLiveNetA-bs32--3train.log &
# epoch: 50 EER: 0.002873 TPR@FPR=10E-2: 1.000000 TPR@FPR=10E-3: 0.961590 APCER:0.002873 NPCER:0.002338 AUC: 0.99985320 Acc:99.729 TN:6595 FP : 19 FN:7 TP:2987  ACER:0.00260535
#
# add avgdown mobilelivefaceB
# 83.05M
# 351220
# nohup python main.py --config="cfgs/MobileLiveNetB-32.yaml" --b 32 --lr 0.01  --every-decay 60 --fl-gamma 3 >> MobileLiveNetB-bs32--train.log &
# epoch: 105 EER: 0.001512 TPR@FPR=10E-2: 0.999788 TPR@FPR=10E-3: 0.996660 APCER:0.004989 NPCER:0.000334 AUC: 0.99996187 Acc:99.646 TN:6581 FP : 33 FN:1 TP:2993  ACER:0.00266171
# nohup python main.py --config="cfgs/MobileLiveNetB-32.yaml" --b 32 --lr 0.01  --every-decay 60 --fl-gamma 3 >> MobileLiveNetB-bs32--2train.log &
# epoch: 47 EER: 0.001670 TPR@FPR=10E-2: 1.000000 TPR@FPR=10E-3: 0.997662 APCER:0.003024 NPCER:0.000334 AUC: 0.99999217 Acc:99.781 TN:6594 FP : 20 FN:1 TP:2993  ACER:0.00167895
# 2019-3-1-13：52
# nohup python main.py --config="cfgs/MobileLiveNetB-32.yaml" --b 32 --lr 0.01  --every-decay 60 --fl-gamma 3 >> MobileLiveNetB-bs32--3train.log &
# epoch: 35 EER: 0.001670 TPR@FPR=10E-2: 1.000000 TPR@FPR=10E-3: 0.996994 APCER:0.004989 NPCER:0.000334 AUC: 0.99998536 Acc:99.646 TN:6581 FP : 33 FN:1 TP:2993  ACE      R:0.00266171
#
#
# shufflenetv2
# + Number of FLOPs: 148.05M
# The network has 1255654 params.
# shufflenetv2_1_bs32
# 2019-3-1-13:13
# nohup python main.py --config="cfgs/shufflenetv2_1.yaml" --lr 0.01 --every-decay 60 -b 32 >> shufflenetv2-1-1train.log &
# shufflenetv2_1_bs32-2
# 2019-3-1-13:15
# nohup python main.py --config="cfgs/shufflenetv2_1.yaml" --lr 0.01 --every-decay 60 -b 32 >> shufflenetv2-1-2train.log &
#
#
# adabound
# 2019-3-2-16:11
# checkpoints/mobilelitenetB_bs32-adabound
# nohup python main.py --config="cfgs/MobileLiteNetB-32.yaml" --b 32 --lr 0.01  --every-decay 60 --fl-gamma 3 >> MobileLiteNetB-bs32-adabound-train.log &
# 2019-3-2-16:19
# checkpoints/mobilelitenetB_bs32-adabound2
# nohup python main.py --config="cfgs/MobileLiteNetB-32.yaml" --b 32 --lr 0.01  --every-decay 60 --fl-gamma 3 >> MobileLiteNetB-bs32-adabound2-train.log &
#
#
# zp
#
# mixup
# mobilelitenetB_bs32-9
# 2019-3-5-12:57
# nohup python main.py --config="cfgs/MobileLiteNetB-32.yaml" --b 32 --lr 0.01  --every-decay 60 --fl-gamma 3 >> MobileLiteNetB-bs32--9train.log &
#
#
# mixup and scheduler_warmup
# 2019-3-5-13:07  15：04
# mobilelitenetB_bs32-10
#
# scheduler_warmup
# 2019-3-5-13:45  15：05
# mobilelitenetB_bs32-11
# nohup python main.py --config="cfgs/MobileLiteNetB-32.yaml" --b 32 --lr 0.01  --every-decay 60 --fl-gamma 3 >> MobileLiteNetB-bs32--11train.log &
#
#
# intel_peng
#
# cifar10
# 2019-3-5-19:03
# FD_mobilenet38_bs32-cifar10-224
# python main-cifar.py --config="cfgs/FD-mobilenetv2.yaml" --lr 0.01 --b 32
# 117 90.4
# 2019-3-5-21:41
# nohup python main-cifar.py --config="cfgs/FD-mobilenetv2.yaml" --lr 0.1 --every-decay 80 -b 64 --resume checkpoints/FD_mobilenet38_bs32-cifar10-224/_117.pth.tar >> cifar10-224-FD-mobilenet-train.log &
#
# 2019-3-5-21:31
# FD_mobilenet38_bs32-cifar10-224-2
# nohup python main-cifar.py --config="cfgs/FD-mobilenetv2.yaml" --lr 0.1 -b 64  --every-decay 80 >> cifar10-224-FD-mobilenet-2train.log & acc 90
#
# 2019-3-5-21:49  adabound 0.2 0.01
# FD_mobilenet38_bs32-cifar10-224-3
# nohup python main-cifar.py --config="cfgs/FD-mobilenetv2.yaml" --lr 0.2 -b 64  --every-decay 80 >> cifar10-224-FD-mobilenet-3train.log & acc 90
#
#
#
#
# ir_final_train
#
# 2019-3-7-18:29
# mobilelitenetB_bs32-ir -b 128 lr 0.01
#
# 2019-3-7-18:31
# mobilelitenetB_bs32-ir2
# nohup python main.py --config="cfgs/MobileLiteNetB-32.yaml" --resume ./checkpoints/mobilelitenetB_bs32/_47_best.pth.tar --lr 0.1 --every-decay 50 >> ir_final_train_bs32.log &
#
#
# 2ir_final_train
#
# 2mobilelitenetB_bs32-ir2
# 2019-3-7-17:01
# nohup python main.py --config="cfgs/MobileLiteNetB-32.yaml" --resume ./checkpoints/mobilelitenetB_bs32/_47_best.pth.tar --lr 0.01 --every-decay 50 >> 2ir_final_train_bs32.log &
# ACC 80.69
#
#
# 3mobilelitenetB_bs32-ir
# 2019-3-8-00：10
# nohup python main.py --config="cfgs/MobileLiteNetB-32.yaml" --resume ./checkpoints/mobilelitenetB_bs32/_47_best.pth.tar --lr 0.01 -b 32 --every-decay 60 --fl-gamma 3 >> 3ir_final_train_mb.log &
# epoch: 59 EER: 0.148897 TPR@FPR=10E-2: 0.215017 TPR@FPR=10E-3: 0.075085 APCER:0.226103 NPCER:0.058020 AUC: 0.92603142 Acc:83.274 TN:421 FP : 123 FN:17 TP:276  ACER:0.14206171
#
# 3mobilelitenetB_bs32-ir2 gamma 2
# 2019-3-8-00：11
# nohup python main.py --config="cfgs/MobileLiteNetB-32.yaml" --resume ./checkpoints/mobilelitenetB_bs32/_47_best.pth.tar --lr 0.01 -b 32 --every-decay 60 --fl-gamma 2 >> 3ir_final_train_mb2.log &
# epoch: 60 EER: 0.147430 TPR@FPR=10E-2: 0.244505 TPR@FPR=10E-3: 0.088737 APCER:0.178309 NPCER:0.119454 AUC: 0.92059827 Acc:84.229 TN:447 FP : 97 FN:35 TP:258  ACER:0.14888137
# epoch: 63 EER: 0.150442 TPR@FPR=10E-2: 0.248874 TPR@FPR=10E-3: 0.064846 APCER:0.185662 NPCER:0.109215 AUC: 0.91822676 Acc:84.110 TN:443 FP : 101 FN:32 TP:261  ACER:0.14743839
#
# 3mobilelitenetB_bs32-ir2 gamma 3 bs 64
# 2019-3-8-00：13
# nohup python main.py --config="cfgs/MobileLiteNetB-32.yaml" --resume ./checkpoints/mobilelitenetB_bs32/_47_best.pth.tar --lr 0.01 -b 64 --every-decay 60 --fl-gamma 3 >> 3ir_final_train_mb3.log &
#
# 3mobilelitenetB_bs16-ir4
# 2019-3-8-09:00
# nohup python main.py --config="cfgs/MobileLiteNetB-32.yaml" --resume ./checkpoints/mobilelitenetB_bs32/_47_best.pth.tar --lr 0.01 -b 16 --every-decay 80 --fl-gamma 2 >> 3ir_final_train_mb4.log &
#
# 4mobilelitenetB_bs32-ir
# 2019-3-8-11:06
# nohup python main.py --config="cfgs/MobileLiteNetB-32.yaml" --resume ./checkpoints/mobilelitenetB_bs32/_47_best.pth.tar --lr 0.01 -b 32 --every-decay 100 --fl-gamma 2 >> 4ir_final_train_mb.log &
#
#
#
# mobilelitenetB_bs32-color
# 2019-3-8-16:11
# nohup python main.py --config="cfgs/MobileLiteNetB-32.yaml" --resume ./checkpoints/mobilelitenetB_bs32/_47_best.pth.tar --lr 0.01 -b 32 --every-decay 100 --fl-gamma 2 >> color_final_train_mb.log &
#
#
# mobilelitenetB_bs32-color2
# 2019-3-8-16:11
# nohup python main.py --config="cfgs/MobileLiteNetB-32.yaml" --resume ./checkpoints/mobilelitenetB_bs32/_47_best.pth.tar --lr 0.01 -b 32 --every-decay 100 --fl-gamma 3 >> color_final_train_mb.log &
#
#
# 他们的全部real和fake中选随机8941
# 2mobilelitenetB_bs32-color
# 2019-3-8-16:11
# nohup python main.py --config="cfgs/MobileLiteNetB-32.yaml" --resume ./checkpoints/mobilelitenetB_bs32/_47_best.pth.tar --lr 0.01 -b 32 --every-decay 100 --fl-gamma 2 >> 2color_final_train_mb.log &
#
# 改了均值和std
# nohup python main.py --config="cfgs/MobileLiteNetB-32.yaml" --resume ./checkpoints/mobilelitenetB_bs32/_47_best.pth.tar --lr 0.01 -b 32 --every-decay 100 --fl-gamma 2 >> 2color_final_train_mb.log &
#
#
#
# ## cifar10
#
# 3-14-14:28 lr 0.1 不收敛准确率10
# nohup python main-cifar10.py --config="cfgs/resnetDW-20.yaml" --lr 0.05 --b 128 --fl-gamma 2 --gpus 1 >> train-cifar10-resnetDW10-20.log &
# 90
# 3-13-16:03
# nohup python main-cifar10.py --config="cfgs/resnetDW.yaml" --lr 0.1 --b 128 --fl-gamma 2 >> train-cifar10-resnetDW10-32.log
# 91
# 3-13-16:33
# nohup python main-cifar10.py --config="cfgs/resnextDW.yaml" --lr 0.1 --b 64 --fl-gamma 2 --gpus 1 >> train-cifar10-resnext29DW_resnext29_8_64.log
#
# 3-13-16:03
# nohup python main-cifar10.py --config="cfgs/resnetDW.yaml" --lr 0.1 --b 128 --fl-gamma 2 >> train-cifar10-resnetDW10-32.log
#
#
#
#
# Mobilelitenet cifar10
# 3-14-14:21
# nohup python main-cifar10.py --config="cfgs/MobileLiteNetA-cifar.yaml" --lr 0.05 --b 32 --fl-gamma 2 >> train-cifar10-MobileLiteNetA.log &
#
#
# 3-14-14:20
# nohup python main-cifar10.py --config="cfgs/MobileLiteNetA-cifar.yaml" --lr 0.05 --b 32 --fl-gamma 3 >> train-cifar10-MobileLiteNetA2.log &
#
#
# 3-14-14:15
# nohup python main-cifar10.py --config="cfgs/MobileLiteNetB-cifar.yaml" --lr 0.05 --b 32 --fl-gamma 2 >> train-cifar10-MobileLiteNetB.log &
#
#
# 3-14-14:08
# nohup python main-cifar10.py --config="cfgs/MobileLiteNetB-cifar.yaml" --lr 0.05 --b 32 --fl-gamma 3 --gpus 1 >> train-cifar10-MobileLiteNetB2.log &
#
#
#
# 3-14-13:55
# mobilelitenetB_cifar-3  增加fc层  if i == 0 and t != 1:
# nohup python main-cifar10.py --config="cfgs/MobileLiteNetB-cifar.yaml" --lr 0.01 --b 32 --fl-gamma 3 --gpus 1 >> train-cifar10-MobileLiteNetB3.log &
